# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import os as os
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Create Data Frame
wine_sales_data_df = pd.read_csv("ifood_df.csv")

# %%
wine_sales_data_df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
#Check columns
for col in wine_sales_data_df.columns:
    print(col)
# Out:
# Income
# Kidhome
# Teenhome
# Recency
# MntWines
# MntFruits
# MntMeatProducts
# MntFishProducts
# MntSweetProducts
# MntGoldProds
# NumDealsPurchases
# NumWebPurchases
# NumCatalogPurchases
# NumStorePurchases
# NumWebVisitsMonth
# AcceptedCmp3
# AcceptedCmp4
# AcceptedCmp5
# AcceptedCmp1
# AcceptedCmp2
# Complain
# Z_CostContact
# Z_Revenue
# Response
# Age
# Customer_Days
# marital_Divorced
# marital_Married
# marital_Single
# marital_Together
# marital_Widow
# education_2n Cycle
# education_Basic
# education_Graduation
# education_Master
# education_PhD
# MntTotal
# MntRegularProds
# AcceptedCmpOverall

# %%
#Check for null values
wine_sales_data_df.isna().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
#Check for duplicated rows
wine_sales_data_df.drop_duplicates(inplace=True)
wine_sales_data_df.shape
# Out:
# (2021, 39)

# %%
wine_sales_data_df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2021.000000  2021.000000  2021.000000  2021.000000  2021.000000
# mean    51687.258783     0.443345     0.509649    48.880752   306.492331
# std     20713.046401     0.536196     0.546393    28.950917   337.603877
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35416.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51412.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68274.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2021.000000      2021.000000      2021.000000       2021.000000
# mean     26.364671       166.059871        37.603662         27.268679
# std      39.776518       219.869126        54.892196         41.575454
# ...

# %%
#Form a data frame to analyze family size,ed, marital status, and wine purchases 
family_winepurchases_df = wine_sales_data_df[["Kidhome", "Teenhome", "marital_Together",
                                                      "marital_Widow", "MntWines", "marital_Divorced", "education_2n Cycle",
                                                      "education_Basic", "education_Graduation", "education_Master",
                                                      "education_PhD", "Income"]]
family_winepurchases_df.head(10)
# Out:
#    Kidhome  Teenhome  marital_Together  marital_Widow  MntWines  \
# 0        0         0                 0              0       635
# 1        1         1                 0              0        11
# 2        0         0                 1              0       426
# 3        1         0                 1              0        11
# 4        1         0                 0              0       173
# 5        0         1                 1              0       520
# 6        0         1                 0              0       235
# 7        1         0                 0              0        76
# 8        1         0                 1              0        14
# 9        1         1                 1              0        28
#
#    marital_Divorced  education_2n Cycle  education_Basic  \
# 0                 0                   0                0
# 1                 0                   0                0
# 2                 0                   0                0
# ...

# %%
for col in family_winepurchases_df.columns:
    print(col)
# Out:
# Kidhome
# Teenhome
# marital_Together
# marital_Widow
# MntWines
# marital_Divorced
# education_2n Cycle
# education_Basic
# education_Graduation
# education_Master
# education_PhD
# Income

# %%
family_winepurchases_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2021 entries, 0 to 2204
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Kidhome               2021 non-null   int64
#  1   Teenhome              2021 non-null   int64
#  2   marital_Together      2021 non-null   int64
#  3   marital_Widow         2021 non-null   int64
#  4   MntWines              2021 non-null   int64
#  5   marital_Divorced      2021 non-null   int64
#  6   education_2n Cycle    2021 non-null   int64
#  7   education_Basic       2021 non-null   int64
#  8   education_Graduation  2021 non-null   int64
#  9   education_Master      2021 non-null   int64
#  10  education_PhD         2021 non-null   int64
#  11  Income                2021 non-null   float64
# dtypes: float64(1), int64(11)
# memory usage: 205.3 KB

# %%
family_winepurchases_df.loc[:,"Kids"] = family_winepurchases_df.loc[:,"Kidhome"] + family_winepurchases_df.loc[:,"Teenhome"]

# %%
family_winepurchases_df.drop(["Kidhome", "Teenhome"], axis=1, inplace=True)

# %%
#Reorder columns
family_winepurchases_df = family_winepurchases_df[["marital_Together","marital_Widow",
                                                "marital_Divorced", "Kids",
                                                "education_2n Cycle","education_Basic", 
                                                "education_Graduation", "education_Master",
                                                "education_PhD", "Income", "MntWines"]]

family_winepurchases_df.head()
# Out:
#    marital_Together  marital_Widow  marital_Divorced  Kids  \
# 0                 0              0                 0     0
# 1                 0              0                 0     2
# 2                 1              0                 0     0
# 3                 1              0                 0     1
# 4                 0              0                 0     1
#
#    education_2n Cycle  education_Basic  education_Graduation  \
# 0                   0                0                     1
# 1                   0                0                     1
# 2                   0                0                     1
# 3                   0                0                     1
# 4                   0                0                     0
#
#    education_Master  education_PhD   Income  MntWines
# 0                 0              0  58138.0       635
# 1                 0              0  46344.0        11
# 2                 0              0  71613.0       426
# ...

# %%
#Sort by wine purchases
family_winepurchases_df.sort_values(by="MntWines", ascending=False)
# Out:
#       marital_Together  marital_Widow  marital_Divorced  Kids  \
# 1723                 0              0                 0     0
# 542                  1              0                 0     1
# 2066                 0              0                 0     1
# 526                  0              0                 0     0
# 1935                 0              1                 0     0
# ...                ...            ...               ...   ...
# 1150                 0              0                 0     0
# 1754                 0              0                 0     1
# 842                  0              0                 0     0
# 2059                 1              0                 0     0
# 1835                 0              0                 1     0
#
#       education_2n Cycle  education_Basic  education_Graduation  \
# 1723                   0                0                     0
# 542                    0                0                     1
# ...

# %%
# Make a new DF that contains only parents
ParentsBuyWine_df = family_winepurchases_df[family_winepurchases_df.Kids > 0]
ParentsBuyWine_df.sort_values(by= "MntWines", ascending=False)
# Out:
#       marital_Together  marital_Widow  marital_Divorced  Kids  \
# 542                  1              0                 0     1
# 2066                 0              0                 0     1
# 1616                 0              0                 1     2
# 1463                 0              0                 0     1
# 480                  1              0                 0     1
# ...                ...            ...               ...   ...
# 718                  0              0                 0     1
# 1754                 0              0                 0     1
# 2084                 0              0                 0     1
# 125                  0              0                 1     1
# 873                  0              0                 0     1
#
#       education_2n Cycle  education_Basic  education_Graduation  \
# 542                    0                0                     1
# 2066                   0                0                     0
# ...

# %%
# Rename the columns
ParentsBuyWine_df.rename(columns={"marital_Together": "Married", "marital_Widow": "Widowed",\
                                    "marital_Divorced": "Divorced", "education_2n Cycle": "2nd Cycle",\
                                    "education_Basic": "Basic", "education_Graduation": "UnderGrad",\
                                    "education_Master": "Master", "education_PhD": "PhD"}, inplace=True)

# %%
#Combine 2nd cycle and master columns into a new column called College using .loc
ParentsBuyWine_df.loc[:,"Masters"] = ParentsBuyWine_df.loc[:,"2nd Cycle"] + ParentsBuyWine_df.loc[:,"Master"]

# %%
#Remove 2nd cycle and Master from the data frame
ParentsBuyWine_df.drop(["2nd Cycle", "Master"], axis=1, inplace=True)

# %%
# Create a customer id column in parntersbuywine_df as the first column in the data frame and assign id's to each row
ParentsBuyWine_df.insert(0, 'Customer ID', range(1, 1 + len(ParentsBuyWine_df)))
ParentsBuyWine_df.head()
# Out:
#    Customer ID  Married  Widowed  Divorced  Kids  Basic  UnderGrad  PhD  \
# 1            1        0        0         0     2      0          1    0
# 3            2        1        0         0     1      0          1    0
# 4            3        0        0         0     1      0          0    1
# 5            4        1        0         0     1      0          0    0
# 6            5        0        0         1     1      0          1    0
#
#     Income  MntWines  Masters
# 1  46344.0        11        0
# 3  26646.0        11        0
# 4  58293.0       173        0
# 5  62513.0       520        1
# 6  55635.0       235        0

# %%
ParentsBuyWine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1454 entries, 1 to 2204
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  1454 non-null   int64
#  1   Married      1454 non-null   int64
#  2   Widowed      1454 non-null   int64
#  3   Divorced     1454 non-null   int64
#  4   Kids         1454 non-null   int64
#  5   Basic        1454 non-null   int64
#  6   UnderGrad    1454 non-null   int64
#  7   PhD          1454 non-null   int64
#  8   Income       1454 non-null   float64
#  9   MntWines     1454 non-null   int64
#  10  Masters      1454 non-null   int64
# dtypes: float64(1), int64(10)
# memory usage: 136.3 KB

# %%
#Drop null values from data frame
ParentsBuyWine_df.dropna(inplace=True)

# %%
#write a for loop to iterate through rows and remove 0 from
#columns masters, phd, basic, graduation, widowed, married, divorced
for index, row in ParentsBuyWine_df.iterrows():
    if row["Masters"] == 0:
        ParentsBuyWine_df.loc[index, "Masters"] = ""
    if row["PhD"] == 0:
        ParentsBuyWine_df.loc[index, "PhD"] = ""
    if row["Basic"] == 0:
        ParentsBuyWine_df.loc[index, "Basic"] = ""
    if row["UnderGrad"] == 0:
        ParentsBuyWine_df.loc[index, "UnderGrad"] = ""
    if row["Widowed"] == 0:
        ParentsBuyWine_df.loc[index, "Widowed"] = ""
    if row["Married"] ==0:
        ParentsBuyWine_df.loc[index, "Married"] = ""
    if row["Divorced"] == 0:
        ParentsBuyWine_df.loc[index, "Divorced"] =""
ParentsBuyWine_df.head()
# Out:
#    Customer ID Married Widowed Divorced  Kids Basic UnderGrad PhD   Income  \
# 1            1                              2               1      46344.0
# 3            2       1                      1               1      26646.0
# 4            3                              1                   1  58293.0
# 5            4       1                      1                      62513.0
# 6            5                        1     1               1      55635.0
#
#    MntWines Masters
# 1        11
# 3        11
# 4       173
# 5       520       1
# 6       235

# %%
#Create a for loop for Basic, Graduation, Master, PhD replace 1 with the education level
#and then combine the columns into a new column called Education and drop the old columns
for index, row in ParentsBuyWine_df.iterrows():
    if row["Basic"] == 1:
        ParentsBuyWine_df.loc[index, "Basic"] = "Basic"
    if row["UnderGrad"] == 1:
        ParentsBuyWine_df.loc[index, "UnderGrad"] = "UnderGrad"
    if row["Masters"] == 1:
        ParentsBuyWine_df.loc[index, "Masters"] = "Masters"
    if row["PhD"] == 1:
        ParentsBuyWine_df.loc[index, "PhD"] = "PhD"
ParentsBuyWine_df["Education"] = ParentsBuyWine_df["Basic"] + ParentsBuyWine_df["UnderGrad"] + ParentsBuyWine_df["Masters"] + ParentsBuyWine_df["PhD"]
ParentsBuyWine_df.drop(["Basic", "UnderGrad", "Masters", "PhD"], axis=1, inplace=True)
ParentsBuyWine_df.head()
# Out:
#    Customer ID Married Widowed Divorced  Kids   Income  MntWines  Education
# 1            1                              2  46344.0        11  UnderGrad
# 3            2       1                      1  26646.0        11  UnderGrad
# 4            3                              1  58293.0       173        PhD
# 5            4       1                      1  62513.0       520    Masters
# 6            5                        1     1  55635.0       235  UnderGrad

# %%
#Create a for loop for Married, Divorced, Widowed replace 1 with the marital status and then combine the columns into a new column called Marital Status and drop the old columns
for index, row in ParentsBuyWine_df.iterrows():
    if row["Married"] == 1:
        ParentsBuyWine_df.loc[index, "Married"] = "Married"
    if row["Divorced"] == 1:
        ParentsBuyWine_df.loc[index, "Divorced"] = "Divorced"
    if row["Widowed"] == 1:
        ParentsBuyWine_df.loc[index, "Widowed"] = "Widowed"
ParentsBuyWine_df["Marital_Status"] = ParentsBuyWine_df["Married"] + ParentsBuyWine_df["Divorced"] + ParentsBuyWine_df["Widowed"]
ParentsBuyWine_df.drop(["Married", "Divorced", "Widowed"], axis=1, inplace=True)
ParentsBuyWine_df.head(10)
# Out:
#     Customer ID  Kids   Income  MntWines  Education Marital_Status
# 1             1     2  46344.0        11  UnderGrad
# 3             2     1  26646.0        11  UnderGrad        Married
# 4             3     1  58293.0       173        PhD
# 5             4     1  62513.0       520    Masters        Married
# 6             5     1  55635.0       235  UnderGrad       Divorced
# 7             6     1  33454.0        76        PhD
# 8             7     1  30351.0        14        PhD        Married
# 9             8     2   5648.0        28        PhD        Married
# 12            9     2  59354.0       233    Masters       Divorced
# 15           10     2  41850.0        53  UnderGrad

# %%
# Export DF
ParentsBuyWine_df.to_csv("ParentsBuyWine_df.csv", index=False)

# %%
 # Add dollar sign and commas to the income and the amount of wine bought columns
ParentsBuyWine_df["Income"] = ParentsBuyWine_df["Income"].map("${:,.2f}".format)
ParentsBuyWine_df["MntWines"] = ParentsBuyWine_df["MntWines"].map("${:,.2f}".format)

# %%
#Print total amount of wines purchased
wine_sum = ParentsBuyWine_df.MntWines.sum()
wine_sum
# Out:
# 337359

# %%
#Plot how much wine was bought by people with PhD's
ParentsBuyWine_df[ParentsBuyWine_df.Education == "PhD"].MntWines.sum()
# Out:
# 99659

# %%
#Print how much revenue from wine was accumulated by education level
print("Parents with a PhD account for", ParentsBuyWine_df[ParentsBuyWine_df.Education == "PhD"]\
                                              .MntWines.sum(), "of Ifood revenue made from wine")
print("Parents with a Master's Degree account for", ParentsBuyWine_df[ParentsBuyWine_df.Education == "Masters"]\
                                              .MntWines.sum(), "of Ifood revenue made from wine")
print("Parents with an Undergrad account for", ParentsBuyWine_df[ParentsBuyWine_df.Education == "UnderGrad"]\
                                              .MntWines.sum(), "of Ifood revenue made from wine")
print("Parents with a Basic education account for", ParentsBuyWine_df[ParentsBuyWine_df.Education == "Basic"]\
                                              .MntWines.sum(), "of Ifood revenue made from wine")
# Out:
# Parents with a PhD account for 99659 of Ifood revenue made from wine
# Parents with a Master's Degree account for 78255 of Ifood revenue made from wine
# Parents with an Undergrad account for 159341 of Ifood revenue made from wine
# Parents with a Basic education account for 104 of Ifood revenue made from wine

# %%
#Print how much revenue from wine was accumulated by marriage status
print("Parents who are married account for", ParentsBuyWine_df[ParentsBuyWine_df["Marital_Status"] == "Married"]\
                                              .MntWines.sum(), "of Ifood revenue made from wine")
print("Parents who are divorced account for", ParentsBuyWine_df[ParentsBuyWine_df["Marital_Status"] == "Divorced"]\
                                              .MntWines.sum(), "of Ifood revenue made from wine")
print("Parents who are widowed account for", ParentsBuyWine_df[ParentsBuyWine_df["Marital_Status"] == "Widowed"]\
                                              .MntWines.sum(), "of Ifood revenue made from wine")
# Out:
# Parents who are married account for 86021 of Ifood revenue made from wine
# Parents who are divorced account for 45814 of Ifood revenue made from wine
# Parents who are widowed account for 14615 of Ifood revenue made from wine

# %%
#Print the average income by education level
print("Average income of parents with Basic education: ", ParentsBuyWine_df[ParentsBuyWine_df.Education == "Basic"\
                                                                           ].Income.mean())
print("Average income of parents with an  Undergrad: ", ParentsBuyWine_df[ParentsBuyWine_df.Education == "UnderGrad"].Income.mean())
                                                                        
print("Average income of parents with a Master's Degree: ", ParentsBuyWine_df[ParentsBuyWine_df.Education == "Masters"\
                                                                             ].Income.mean())
print("Average income of parents with a PhD: ", ParentsBuyWine_df[ParentsBuyWine_df.Education == "PhD"].Income.mean())
# Out:
# Average income of parents with Basic education:  19400.08823529412
# Average income of parents with an  Undergrad:  46524.703296703294
# Average income of parents with a Master's Degree:  45705.32249322493
# Average income of parents with a PhD:  49036.32817337461

# %%
#Print the average income by marital status
print("Average income of parents who are maried: ", ParentsBuyWine_df[ParentsBuyWine_df.Marital_Status == "Married"\
                                                                       ].Income.mean())
print("Average income of parents who are divorced: ", ParentsBuyWine_df[ParentsBuyWine_df.Marital_Status == "Divorced"\
                                                                       ].Income.mean())
print("Average income of parents who are widowed: ", ParentsBuyWine_df[ParentsBuyWine_df.Marital_Status == "Widowed"\
                                                                      ].Income.mean())
# Out:
# Average income of parents who are maried:  45911.688829787236
# Average income of parents who are divorced:  48954.801242236026
# Average income of parents who are widowed:  53353.066666666666

# %%
#Print the average amount of wines purchased by marital status and degree level
print("Average wines bought by marital status")
print("Average amount spent on wine bought by parents who are married: ", ParentsBuyWine_df[ParentsBuyWine_df.Marital_Status\
                                                                                     == "Married"].MntWines.mean())
print("Average amount spent on wine bought by parents who are divorced: ", ParentsBuyWine_df[ParentsBuyWine_df.Marital_Status\
                                                                                     == "Divorced"].MntWines.mean())
print("Average amount spent on wine bought by parents who are widowed: ", ParentsBuyWine_df[ParentsBuyWine_df.Marital_Status\
                                                                                   == "Widowed"].MntWines.mean())
print("") 
print("Average spent on wine by education level")
print("Average amount spent on wine bought by parents who hold a basic education: ", ParentsBuyWine_df[ParentsBuyWine_df.\
                                                                                Education == "Basic"].MntWines.mean())
print("Average amount spent on wine bought by parents who hold an undergrad: ", ParentsBuyWine_df[ParentsBuyWine_df.Education\
                                                                                        == "UnderGrad"].MntWines.mean())
print("Average amount spent on bought by parents who hold a Master's Degree: ", ParentsBuyWine_df[ParentsBuyWine_df.\
                                                                                Education == "Masters"].MntWines.mean())
print("Average amount spent on bought by parents who hold a PhD: ", ParentsBuyWine_df[ParentsBuyWine_df.Education\
                                                                                    == "PhD"].MntWines.mean())
# Out:
# Average wines bought by marital status
# Average amount spent on wine bought by parents who are married:  228.77925531914894
# Average amount spent on wine bought by parents who are divorced:  284.55900621118013
# Average amount spent on wine bought by parents who are widowed:  324.77777777777777
#
# Average spent on wine by education level
# Average amount spent on wine bought by parents who hold a basic education:  3.0588235294117645
# Average amount spent on wine bought by parents who hold an undergrad:  218.875
# Average amount spent on bought by parents who hold a Master's Degree:  212.0731707317073
# Average amount spent on bought by parents who hold a PhD:  308.54179566563465

# %%
#ParentsBuyWine_df["Education"] = ParentsBuyWine_df["Education"].astype(str)

# %%
#Count the parents by degree status in the data set. 

print("Amount of parents by education status: ", ParentsBuyWine_df.Education.value_counts())
# Out:
# Amount of parents by education status:  UnderGrad    728
# Masters      369
# PhD          323
# Basic         34
# Name: Education, dtype: int64

# %%
#Caclulate the percentages of each education level. 
ParentsBuyWine_df.Education.value_counts(normalize=True)
# Out:
# UnderGrad    0.500688
# Masters      0.253783
# PhD          0.222146
# Basic        0.023384
# Name: Education, dtype: float64

# %%
#Gather statistical measurements
ParentsBuyWine_df.Income.describe()
# Out:
# count     1454.000000
# mean     46240.429849
# std      17251.920023
# min       2447.000000
# 25%      33562.500000
# 50%      45947.500000
# 75%      59301.000000
# max      94871.000000
# Name: Income, dtype: float64

# %%
#Gather statistical measurements
ParentsBuyWine_df.MntWines.describe()
# Out:
# count    1454.00000
# mean      232.02132
# std       292.54507
# min         0.00000
# 25%        18.00000
# 50%        96.00000
# 75%       369.75000
# max      1492.00000
# Name: MntWines, dtype: float64
